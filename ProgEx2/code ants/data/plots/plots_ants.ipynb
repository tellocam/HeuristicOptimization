# %%
import pandas as pd
import glob
import matplotlib.pyplot as plt
import numpy as np
import os
from pylab import rcParams
import matplotlib.cm as cm
from matplotlib import colors
from matplotlib.ticker import MaxNLocator
import seaborn as sns
from matplotlib.colors import ListedColormap

save_figures_to_latex = True
figures_path = '../../latex1/figures'     # to change if notebook is used in future exercises

# %%
rcParams['figure.figsize'] = 5, 3
plt.rc('text', usetex=True)
plt.rcParams['text.usetex']=True
plt.rc('font', family='sans-serif', weight='bold')

SMALL_SIZE = 7
MEDIUM_SIZE = 9
BIGGER_SIZE = 10

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=MEDIUM_SIZE)    # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title
plt.rcParams['figure.dpi'] = 1000

# %%
# with open('objval_vs_iter_genetic.txt', 'r') as file:
#     first_line = file.readline().strip()

# # Split the line into a list of numbers
# numbers = [float(num) for num in first_line.split(';') if num]

# # Create a DataFrame with a single column
# df = pd.DataFrame({'Data': numbers})

# # Plotting the data against the row index
# plt.plot(df.index, df['Data'], linestyle='-')

# plt.xlabel("Iteration / -")
# plt.ylabel("Objective Value / -")
# plt.title("Objective Behavior for Genetic Algorithm - heur050 competition")
# plt.tight_layout()
# plt.grid(alpha=0.2)

# save_figures = False
# if (save_figures == True):
#     plt.savefig("objval_vs_iter_genetic.pdf", format='pdf')

# %%
# Create a DataFrame with a single column
df = pd.read_csv("objval_vs_iter_ants.txt", header=None, names=['Data'])
# Plotting the data against the row index
plt.plot(df.index, df['Data'], linestyle='-')

plt.xlabel("Iteration / -")
plt.ylabel("Objective Value / -")
plt.title("Objective Behavior for Ant Colony System Algorithm - heur050 competition")
plt.tight_layout()
plt.grid(alpha=0.2)

save_figures = True
if (save_figures == True):
    plt.savefig("objval_vs_iter_ant.pdf", format='pdf')

# %%
regex_pattern = r'_n_(\d+)_m_(\d+)\.txt'
import os
import pandas as pd

regex_pattern = r'_n_(\d+)_m_(\d+)\.txt'

df_genetic = pd.read_csv("results_genetic.csv", delimiter='\,', header=0, index_col=False, engine='python')  # Use the first row as column names
df_genetic.reset_index()
df_genetic[['n', 'm']] = df_genetic['inst_file'].str.extract(regex_pattern).astype(int)
df_genetic['nm'] = df_genetic['n'] + df_genetic['m']
print(df_genetic.columns)

df_ants = pd.read_csv("all_solutions_test_ants.txt", delimiter=',', header=0)  # Assuming ',' is the delimiter
# Out:
# Index(['inst_file', 'N', 'T', 'max_useless_gens', 'overlap',
#        'selected_percentage', 'recomb_meth', 'n_elites', 'selection_pressure',
#        'time', 'obj_val', 'n', 'm', 'nm'],
#       dtype='object')

# %%
# # Strip leading/trailing whitespaces from column names
# df_ants.columns = df_ants.columns.str.strip()
# df_genetic.columns = df_genetic.columns.str.strip()

# # Reset the index for each dataframe
# df_ants_reset = df_ants.reset_index(drop=True)
# df_genetic_reset = df_genetic.reset_index(drop=True)

# # Set the color maps for ants (blue) and genetic (red)
# blue_cmap = sns.light_palette("blue", as_cmap=True)
# red_cmap = sns.light_palette("red", as_cmap=True)

# # Create a scatter plot for ants (blue)
# scatter_ants = plt.scatter(df_ants_reset['m'], df_ants_reset['time'], c=df_ants_reset['n'], cmap=blue_cmap, marker='o', s=50, label='Ants')
# # Create a scatter plot for genetic (red)
# scatter_genetic = plt.scatter(df_genetic_reset['m'], df_genetic_reset['time'], c=df_genetic_reset['n'], cmap=red_cmap, marker='o', s=50, label='Genetic')



# # Add colorbar for 'n' values (to the right)
# cbar_ants = plt.colorbar(scatter_ants, label='Number of Vertices', orientation="vertical", ticks=[120, 180, 240, 300, 360])

# # Add colorbar for 'n' values (to the left)
# cbar_genetic = plt.colorbar(scatter_genetic, orientation="vertical", ticks=[120, 180, 240, 300, 360])
# cbar_genetic.ax.yaxis.set_label_position('right')  # Position the label to the left


# plt.title("GA vs. ACS - Objective Value", color='black')
# plt.legend(["GA - Red", "ACS - Blue"])
# plt.xlabel("Number of Edges / -")
# plt.ylabel("Elapsed Time / -")
# plt.grid(alpha=0.2)

# save_figures = False
# if (save_figures == True):
#     plt.savefig("elapsedTime_vs_edges_both.pdf", format='pdf')
